# %% [markdown]
# sets

# %%
set1={"red","blue","black"}
print(set1)
# Out:
# {'blue', 'black', 'red'}

# %%
set1={"red","blue","black","red"}
print(set1)
# Out:
# {'blue', 'black', 'red'}

# %%
set1.add('orange')
print(set1)
# Out:
# {'blue', 'orange', 'black', 'red'}

# %% [markdown]
# add two sets

# %%
set2={"ball","bat","wicket"}
set1.update(set2)
print(set1)
# Out:
# {'bat', 'orange', 'red', 'wicket', 'blue', 'black', 'ball'}

# %% [markdown]
# Dictioneries

# %%
Dict1={"name":"nagveni","age":"32","gender":"female"}
print(Dict1)
# Out:
# {'name': 'nagveni', 'age': '32', 'gender': 'female'}

# %%
Dict2={"name":"nagveni","age":"32","gender":"female","year":"2022","year":"2016"}
print(Dict2)
# Out:
# {'name': 'nagveni', 'age': '32', 'gender': 'female', 'year': '2016'}

# %%
print(type(Dict1))
# Out:
# <class 'dict'>

# %% [markdown]
# using constructors in dictionary

# %%
Dict3=dict(fruit="bananna",desert="ice")
print(Dict3)
# Out:
# {'fruit': 'bananna', 'desert': 'ice'}

# %%
print(type(Dict3))
# Out:
# <class 'dict'>
